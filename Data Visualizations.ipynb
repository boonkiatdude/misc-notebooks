# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas.plotting import autocorrelation_plot
from pandas.plotting import scatter_matrix
from pandas.plotting import parallel_coordinates
from pandas.plotting import lag_plot

# %%
mpg = sns.load_dataset('mpg')
tip = sns.load_dataset('tips')
att = sns.load_dataset('attention')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
att.head()
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
plt.scatter(mpg['acceleration'], mpg['horsepower'], marker='^', color='purple')
plt.xlabel('Acceleration')
plt.ylabel('Horsepower')
plt.tight_layout()
plt.show()

# %%
mpg.plot.hexbin(x='acceleration', y='horsepower', cmap='YlGnBu', gridsize=20)
plt.show()

# %%
sns.heatmap(mpg.corr(), annot=True, cmap='YlGnBu')

# %%
autocorrelation_plot(tip.total_bill)
plt.show()

# %%
lag_plot(tip['total_bill'], s=10)
plt.show()

# %%
parallel_coordinates(att, 'attention', color=('#556270', '#C7F464'))
plt.show()
